# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#to set style for count plot use sns.set_style('style you want') refer to docs for the styles and more info
sns.set_style('whitegrid')
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#to remove the spines/axis on the left, right, top, bottom use sns.despine() in this top and right are True by default, if you wanna remove other spines, specify them
sns.countplot(data=tips, x='sex')
sns.despine(left=True, bottom=True)

# %%
#to resize the plots, use matplotlib commands to resize your seaborn plots
#ALWAYS SET FIGSIZE BEFORE THE PLOT else it won't work
plt.figure(figsize=(12,3))
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#to set plot size using seaborn argument use sns.set_context('context you want', (optional)font_scale=int) where for context like 'poster', 'notebook', etc, refer to docs for more info & font_scale is optional if you wanna change font size wrt default font size
sns.set_context('poster', font_scale=2)
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#for changing colors of the plots, hues use the argument palette='palette you want' in the plot statement, refer to docs for all the palettes
sns.set_context('notebook')
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', palette='seismic')
