# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#to get a scatter plot with linear fit use sns.lmplot(data=dataset, x='col name', y='col name')
sns.lmplot(data=tips, x='total_bill', y='tip')

# %%
#to get plot wrt categorical data, use hue argument to get different hues for different categories with their respective scatter plots and linear fits
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex')

# %%
#to change the markers for each category in hue, use markers argument as markers=['type', 'type'] where type is the type of marker you wanna use, refer to docs for more info
#to change the size of the markers use the matplotlib argument for scatter plot in this case- scatter_kws={'s':int} where this argument is used to modify the scatter plot and s is for the size of the markers, refer to docs for more info
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', markers=['o','v'], scatter_kws={'s':100})
