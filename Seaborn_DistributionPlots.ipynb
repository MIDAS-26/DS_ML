# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#to get a histogram use sns.histplot(dataframe['column name'])
#the bars in the histogram are reffered to as bins, to get more bins in the histogram use argument bins=int

sns.histplot(tips['total_bill'], bins=50)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
#to get a joint plot use sns.jointplot(x='column name', y='column name', data=dataframe)
#the default centre plot is scatter plot, to change it use argument kind='the kinda plot you want'(eg. hex, reg, kde)
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
#to get plot for all numerical columns in the dataframe, use sns.pairplot(dataframe)
#for a plot for a column vs itself, it plots a histogram, for rest a scatter plot
sns.pairplot(tips)

# %%
#to get plots with categorical info, use hue argument in pairplot(dataframe, hue='column name')
# categorical column has non continuous, category like data eg. Sex- Male, Female
sns.pairplot(tips, hue='sex')

# %%
#rugplot is a plot where you drop a dash for every point to be plotted on the graph
#use sns.rugplot(dataframe['column name'])
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>
